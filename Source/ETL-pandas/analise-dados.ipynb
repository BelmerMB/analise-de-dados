# %%
import pandas as pd
import matplotlib.pyplot as mpl

# %%
pd.read_csv('../../Dados/alunos.csv', sep=',')
# Out:
#               name escolaridade         notas regiao  idade
# 0         John Doe  High School  [85, 90, 78]  North     17
# 1       Jane Smith      College  [92, 88, 95]  South     20
# 2     Alex Johnson  High School  [76, 82, 70]   East     16
# 3      Emily Davis      College  [89, 91, 87]   West     22
# 4    Michael Brown  High School  [80, 75, 82]  North     18
# 5     Sophia White      College  [94, 96, 90]  South     21
# 6  Daniel Martinez  High School  [72, 68, 75]   East     17
# 7    Olivia Taylor      College  [87, 89, 92]   West     19
# 8   Ethan Anderson  High School  [78, 80, 74]  North     16
# 9       Ava Wilson      College  [91, 93, 88]  South     20

# %%
alunos = pd.read_csv('../../Dados/alunos.csv', sep=',')

# %%
#alunos = alunos[alunos['escolaridade'] == 'College']

# %%
#alunos[alunos['idade'] >= 17]

# %%
df = pd.DataFrame(alunos)

# %%
idade = df['idade']
college = df['escolaridade']

# %%
mpl.plot(idade, college)

# %%
idades = [ 23, 78, 22, 19, 45]
nomes = ['João', 'Ana', 'Carlos', 'Maria', 'Pedro']

# %%
mpl.bar(nomes, idades)
mpl.xlabel('nomes')
mpl.ylabel('idades')
mpl.show()
